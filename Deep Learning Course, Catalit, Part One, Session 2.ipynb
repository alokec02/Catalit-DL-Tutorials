# %% [markdown]
# # EDA with Pandas

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/aloke/Downloads/titanic-train.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Indexing

# %%
df.iloc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                      35
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
df.loc[0:4, 'Ticket']
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %%
df['Ticket'].head()
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %%
df[['Embarked', 'Ticket']].head()
# Out:
#   Embarked            Ticket
# 0        S         A/5 21171
# 1        C          PC 17599
# 2        S  STON/O2. 3101282
# 3        S            113803
# 4        S            373450

# %% [markdown]
# # Selections

# %%
df[df['Age']>70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df.query("Age>70")
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df[(df['Age']==11) & (df['SibSp']==5)]
# Out:
#     PassengerId  Survived  Pclass                                Name   Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick  male
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59  11.0      5      2  CA 2144  46.9   NaN        S

# %%
df[(df['Age']==11) | (df['SibSp']==5)]
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 59            60         0       3   Goodwin, Master. William Frederick
# 71            72         0       3           Goodwin, Miss. Lillian Amy
# 386          387         0       3      Goodwin, Master. Sidney Leonard
# 480          481         0       3       Goodwin, Master. Harold Victor
# 542          543         0       3    Andersson, Miss. Sigrid Elisabeth
# 683          684         0       3          Goodwin, Mr. Charles Edward
# 731          732         0       3             Hassan, Mr. Houssein G N
# 802          803         1       1  Carter, Master. William Thornton II
#
#         Sex   Age  SibSp  Parch   Ticket      Fare    Cabin Embarked
# 59     male  11.0      5      2  CA 2144   46.9000      NaN        S
# 71   female  16.0      5      2  CA 2144   46.9000      NaN        S
# 386    male   1.0      5      2  CA 2144   46.9000      NaN        S
# ...

# %%
df.query('(Age==11) | (SibSp == 5)')
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 59            60         0       3   Goodwin, Master. William Frederick
# 71            72         0       3           Goodwin, Miss. Lillian Amy
# 386          387         0       3      Goodwin, Master. Sidney Leonard
# 480          481         0       3       Goodwin, Master. Harold Victor
# 542          543         0       3    Andersson, Miss. Sigrid Elisabeth
# 683          684         0       3          Goodwin, Mr. Charles Edward
# 731          732         0       3             Hassan, Mr. Houssein G N
# 802          803         1       1  Carter, Master. William Thornton II
#
#         Sex   Age  SibSp  Parch   Ticket      Fare    Cabin Embarked
# 59     male  11.0      5      2  CA 2144   46.9000      NaN        S
# 71   female  16.0      5      2  CA 2144   46.9000      NaN        S
# 386    male   1.0      5      2  CA 2144   46.9000      NaN        S
# ...

# %% [markdown]
# # Unique Values

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# # Sorting

# %%
df.sort_values('Age', ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %% [markdown]
# # Group By, Pivot Tables, Correlations

# %%
df.groupby(['Pclass', 'Survived'])['PassengerId'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: PassengerId, dtype: int64

# %%
df.pivot_table(index='Pclass', columns='Survived', values='PassengerId', aggfunc='count')
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
correlated_with_survived = df.corr()['Survived'].sort_values()

# %%
correlated_with_survived
# Out:
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# PassengerId   -0.005007
# Parch          0.081629
# Fare           0.257307
# Survived       1.000000
# Name: Survived, dtype: float64

# %% [markdown]
# # Visaul Data Exploration with Matplotlib

# %%
data1 = np.random.normal(0, 0.1, 1000)
data2 = np.random.normal(1, 0.4, 1000) + np.linspace(0, 1, 1000)
data3 = 2 + np.random.random(1000) * np.linspace(1, 5, 1000)
data4 = np.random.normal(3, 0.2, 1000) + 0.3 * np.sin(np.linspace(0, 20, 1000))

# %%
data = np.vstack([data1, data2, data3, data4]).transpose()

# %%
df = pd.DataFrame(data, columns=['data1', 'data2', 'data3', 'data4'])
df.head()
# Out:
#       data1     data2     data3     data4
# 0  0.030344 -0.030596  2.599522  2.528965
# 1 -0.082259  1.423413  2.030593  3.130105
# 2 -0.086659  1.381655  2.399700  2.741363
# 3  0.112314  1.347456  2.951597  2.977041
# 4  0.036834  0.951895  2.808878  3.035539

# %% [markdown]
# # Line Plot

# %%
df.plot(title = 'Line plot')
# Out:
# <AxesSubplot:title={'center':'Line plot'}>

# %%
plt.plot(df)
plt.title('Line plot')
plt.legend(['data1', 'data2', 'data3', 'data4'])

# %% [markdown]
# # Scatter Plot

# %%
df.plot(style='.')
# Out:
# <AxesSubplot:>

# %%
_ = df.plot(kind='scatter', x='data1', y='data2', xlim=(-1.5, 1.5), ylim=(0,3))

# %% [markdown]
# # Histograms

# %%
df.plot(kind='hist',
       bins=50,
       title='Histogram',
       alpha=0.6)
# Out:
# <AxesSubplot:title={'center':'Histogram'}, ylabel='Frequency'>

# %%
df.plot(kind='hist',
       bins=100,
       title='Cumulative distributions',
       cumulative=True,
       alpha=0.4)
# Out:
# <AxesSubplot:title={'center':'Cumulative distributions'}, ylabel='Frequency'>

# %% [markdown]
# # Box Plot

# %%
df.plot(kind='box', title='Boxplot')
# Out:
# <AxesSubplot:title={'center':'Boxplot'}>

# %% [markdown]
# # Subplots

# %%
fig, ax = plt.subplots(2,2, figsize=(16,12))

df.plot(ax=ax[0][0],
       title='Line plot')

df.plot(ax=ax[0][1],
       style='o',
       title='Scatter plot')

df.plot(ax=ax[1][0],
       kind='hist',
       bins=50,
       title='Histogram')

df.plot(ax=ax[1][1],
       kind='box',
       title='Boxplot')
# Out:
# <AxesSubplot:title={'center':'Boxplot'}>

# %% [markdown]
# # Pie charts

# %%
gt01 = df['data1']>0.1
piecounts = gt01.value_counts()
piecounts
# Out:
# False    835
# True     165
# Name: data1, dtype: int64

# %%
piecounts.plot(kind='pie',
              figsize=(5,5),
              explode=[0, 0.15],
              labels=['<= 0.1', '>0.1'],
              autopct='%1.1f%%',
              shadow=True,
              startangle=90,
              fontsize=16)
# Out:
# <AxesSubplot:ylabel='data1'>

# %% [markdown]
# # Hexbin plot

# %%
data = np.vstack([np.random.normal((0,0), 2, size=(1000, 2)),
                 np.random.normal((9,9), 3, size=(2000, 2))])
df = pd.DataFrame(data, columns=['x', 'y'])

# %%
df.head()
# Out:
#           x         y
# 0  1.409594 -0.337128
# 1  2.247964  3.673929
# 2 -1.742609  3.181857
# 3 -4.037104  1.054044
# 4 -2.330340 -1.234558

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hexbin', x='x', y='y', bins=100, cmap='rainbow')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Unstructured Data

# %%
from PIL import Image

# %%
img = Image.open("C:/Users/aloke/Downloads/iss.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x435 at 0x16B2B61B9D0>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imgarray=np.asarray(img)

# %%
type(imgarray)
# Out:
# numpy.ndarray

# %%
imagarray.shape
# Out:
# (435, 640, 3)

# %%
imgarray.ravel().shape
# Out:
# (835200,)

# %% [markdown]
# # Sound

# %%
from scipy.io import wavfile

# %%
rate, snd = wavfile.read(filename="C:/Users/aloke/Downloads/data_sms.wav")

# %%
from IPython.display import Audio

# %%
Audio(data=snd, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(snd)
# Out:
# 110250

# %%
snd
# Out:
# array([70, 14, 27, ..., 58, 68, 59], dtype=int16)

# %%
plt.plot(snd)

# %%
_=plt.specgram(snd, NFFT=1024, Fs=44100)
plt.ylabel('Frequency (Hz)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %% [markdown]
# # EDA Exercises

# %% [markdown]
# # Exercise 1

# %%
df = pd.read_csv("C:/Users/aloke/Downloads/international-airline-passengers.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                144 non-null    object
#  1   Thousand Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df.head()
# Out:
#      Month  Thousand Passengers
# 0  1949-01                  112
# 1  1949-02                  118
# 2  1949-03                  132
# 3  1949-04                  129
# 4  1949-05                  121

# %%
df['Month']=pd.to_datetime(df['Month'])
df = df.set_index('Month')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Thousand Passengers  144 non-null    int64
# dtypes: int64(1)
# memory usage: 2.2 KB

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# # Exercise 2

# %%
df = pd.read_csv("C:/Users/aloke/Downloads/weight-height.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.plot(kind='scatter', x='Height', y='Weight')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
male=df[df['Gender']=='Male']
female=df[df['Gender']=='Female']

_=plt.scatter(x=male['Height'], y=male['Weight'], color='blue', alpha=0.3)
_=plt.scatter(x=female['Height'], y=female['Weight'], color='red', alpha=0.3)
plt.title("Male & Female Populations")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Female    5000
# Male      5000
# Name: Gender, dtype: int64

# %%
df['Gendercolor']=df['Gender'].map({'Male':'blue', 'Female':'red'})
df.head()
# Out:
#   Gender     Height      Weight Gendercolor
# 0   Male  73.847017  241.893563        blue
# 1   Male  68.781904  162.310473        blue
# 2   Male  74.110105  212.740856        blue
# 3   Male  71.730978  220.042470        blue
# 4   Male  69.881796  206.349801        blue

# %%
df.plot(kind='scatter', x='Height', y='Weight', c='Gendercolor')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %% [markdown]
# # Exercise 3

# %%
a=df[df['Gender']=='Male']

b=df[df['Gender']=='Female']

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       5000 non-null   object
#  1   Height       5000 non-null   float64
#  2   Weight       5000 non-null   float64
#  3   Gendercolor  5000 non-null   object
# dtypes: float64(2), object(2)
# memory usage: 195.3+ KB

# %%
a.head()
# Out:
#   Gender     Height      Weight Gendercolor
# 0   Male  73.847017  241.893563        blue
# 1   Male  68.781904  162.310473        blue
# 2   Male  74.110105  212.740856        blue
# 3   Male  71.730978  220.042470        blue
# 4   Male  69.881796  206.349801        blue

# %%
b.head()
# Out:
#       Gender     Height      Weight Gendercolor
# 5000  Female  58.910732  102.088326         red
# 5001  Female  65.230013  141.305823         red
# 5002  Female  63.369004  131.041403         red
# 5003  Female  64.479997  128.171511         red
# 5004  Female  61.793096  129.781407         red

# %%
male['Height'].plot(kind='hist', 
                    bins=50,
                    range=(50,80),
                    alpha=0.3,
                    color='blue')

female['Height'].plot(kind='hist', 
                    bins=50,
                    range=(50,80),
                    alpha=0.3,
                    color='red')
plt.title('Height distribution')
plt.legend(['Males', 'Females'])
plt.xlabel('Height (in)')

plt.axvline(male['Height'].mean(), color='blue', linewidth=2)
plt.axvline(female['Height'].mean(), color='red', linewidth=2)

# %%
male['Height'].plot(kind='hist', 
                    bins=200,
                    range=(50,80),
                    alpha=0.3,
                    color='blue',
                    cumulative=True,
                    density=True, 
                    stacked = True)

female['Height'].plot(kind='hist', 
                    bins=200,
                    range=(50,80),
                    alpha=0.3,
                    color='red',
                    cumulative=True, 
                    density=True, 
                    stacked = True)

plt.title('Height distribution')
plt.legend(['Males', 'Females'])
plt.xlabel('Height (in)')

plt.axhline(0.8)
plt.axhline(0.5)
plt.axhline(0.2)

# %% [markdown]
# # Exercise 4

# %%
dfpvt = df.pivot(columns = 'Gender', values = 'Weight')
dfpvt.head()
# Out:
# Gender  Female        Male
# 0          NaN  241.893563
# 1          NaN  162.310473
# 2          NaN  212.740856
# 3          NaN  220.042470
# 4          NaN  206.349801

# %%
dfpvt.plot(kind='box')
plt.title('Weight Box Plot')
plt.ylabel('Weight (lbs)')
# Out:
# Text(0, 0.5, 'Weight (lbs)')

# %% [markdown]
# # Exercise 5

# %%
df = pd.read_csv("C:/Users/aloke/Downloads/titanic-train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.plotting.scatter_matrix(df.drop('PassengerId', axis=1), figsize=(10,10))
# Out:
# array([[<AxesSubplot:xlabel='Survived', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Age', ylabel='Survived'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Parch', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Survived'>],
#        [<AxesSubplot:xlabel='Survived', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='Age', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='Parch', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Pclass'>],
#        [<AxesSubplot:xlabel='Survived', ylabel='Age'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='Age'>,
#         <AxesSubplot:xlabel='Age', ylabel='Age'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='Age'>,
#         <AxesSubplot:xlabel='Parch', ylabel='Age'>,
# ...
